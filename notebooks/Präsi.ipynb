# %% [markdown]
# # **TravelTide Rewards & Segmentierung**

# %% [markdown]
# ## **Machine Learning gestützte Datenanalyse zur Segmentierung der Kunden und Einführung eines Bonusprogramms**

# %% [markdown]
# ## **Problemstellung** Folie 1
#
# * **TravelTide verfügt über ca. 1 Mio. Nutzer:innen und mehr als 5 Mio. App-Sessions.**
# Bilder: Tabelle mit Anzahlzeile in Millionen pro Tabelle
#
# * **Aufgabe:** Diese aktiven Nutzer:innen in **Segmente** unterteilen und ihnen **passende Prämien** zuordnen (Rabatte, Gratisgepäck und usw.).
#
# * **Ziel:** Einführung eines **Bonusprogramms**, das Aktivität, Engagement und Wiederbuchungen deutlich steigert.
#
# ## **Aktive Nutzer:innen** Folie 2
# Gesamtzahl: 1,6 Mio. Nutzer:innen
# Filter: ≥7 Sessions seit dem 4. Januar 2023 → 5.998 berechtigte Nutzer:innen
# Analysezeitraum: Nur aktuelle Sessions und Reisen
# Visual: Zeitstrahl mit Cutoff und Sessionfilter
#
# Bilder: Timeline aus Learning Journey (Filter)
#
# ## **Nutzer Segmentierung & Prämienlogik Folie 3
#
#
# * **Perk-Scores** pro Segment (Ausgaben, Reisen, Stornierungen)
# * **Priorisierung großer Segmente** nach Score-Höhe
# * **Einmalige Perk-Vergabe**, außer *exklusive Rabatte* als Fallback
#
# ------
#
# * **5 Kundensegmente** basierend auf Verhalten & Aktivität
#
# * **Prämienzuordnung** über definierte Metriken (Sessions, Sparverhalten, Gepäck)
#
# Bilder: Balkendiagramm mit Perksgruppe und Anzahl (mit Segment table bild in Canva erstellen)
#
# ## **Nutzergruppe** Folie 4,5,6
# **Folie 4** Gruppe 1&4
# . Business Travellers: viele Reisen, hohe Frequenz, serviceorientiert
#
# . VIP High Spenders: hoher Umsatz, Premium-Erwartung, hohe Loyalität
#
# Perk : Flexibilität, Komfort-Vorteile, Premium-Rewards
#
# Beispiel ein Geschäftsreisende Nutzer
#
# **Folie 5**
# Baseline : Geringe Reiseaktivität, Niedrige Anzahl an Trips
# Perk: no cancelation fees
#
# Group Travellers / Heavy Baggage: Hohe Reisekosten & größere Gruppen , Viele Gepäckstücke Perk: free checked bag
# Senior bsp
# **Folie 6**
# Browers Exclusive : Hoher Anteil an Suchaktivität (viele Sessions, wenig Buchungen), Mittlere Ausgaben & gelegentliche Buchungen
#
# Perk: exclusive discounts (Rabattanreize wirken am stärksten)
# ## **Erkenntnisse** Folie 7
# negative Nächte
# ## **Empfehlung** Folie 8

# %% [markdown]
# SEGMENT SUMMARY
# ================================================================================
#                                Segment         Assigned Perk  Count Percentage Avg Spend Avg Trips
# VIP high spenders & frequent travelers one night with flight    522       8.7%      $993       4.4
#                   Browsers or spenders   exclusive discounts   1025      17.1%      $755       3.8
#       Group travelers or heavy baggage     free checked bags   1525      25.4%     $1503       2.5
#     Hotel lovers or business travelers       free hotel meal   1069      17.8%     $1579       3.7
#                               Baseline   no cancelation fees   1857      31.0%      $962       1.6
